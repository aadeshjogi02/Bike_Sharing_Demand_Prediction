# %% [markdown]
# # <b><u> Project Title : Seoul Bike Sharing Demand Prediction </u></b>

# %% [markdown]
# ## <b> Problem Description </b>
#
# ### Currently Rental bikes are introduced in many urban cities for the enhancement of mobility comfort. It is important to make the rental bike available and accessible to the public at the right time as it lessens the waiting time. Eventually, providing the city with a stable supply of rental bikes becomes a major concern. The crucial part is the prediction of bike count required at each hour for the stable supply of rental bikes.

# %% [markdown]
# ## <b> Data Description </b>
#
# ### <b> The dataset contains weather information (Temperature, Humidity, Windspeed, Visibility, Dewpoint, Solar radiation, Snowfall, Rainfall), the number of bikes rented per hour and date information.</b>
#
#
# ### <b>Attribute Information: </b>
#
# * ### Date : year-month-day
# * ### Rented Bike count - Count of bikes rented at each hour
# * ### Hour - Hour of he day
# * ### Temperature-Temperature in Celsius
# * ### Humidity - %
# * ### Windspeed - m/s
# * ### Visibility - 10m
# * ### Dew point temperature - Celsius
# * ### Solar radiation - MJ/m2
# * ### Rainfall - mm
# * ### Snowfall - cm
# * ### Seasons - Winter, Spring, Summer, Autumn
# * ### Holiday - Holiday/No holiday
# * ### Functional Day - NoFunc(Non Functional Hours), Fun(Functional hours)

# %% [markdown]
# #<b> Install & Import Modules

# %%
# importing numpy and pandas
import pandas as pd

# Importing Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## <b> Loading the dataset

# %%
data= pd.read_csv(r"H:\indain_bike_demand_share_syntheic_dataset.csv", encoding = "ISO-8859-1")
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data= pd.read_csv(r"H:\indain_bike_demand_share_syntheic_dataset.csv", encoding = "ISO-8859-1")
#       2 data
#
# File c:\Users\aades\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\aades\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\aades\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\aades\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\aades\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'H:\\indain_bike_demand_share_syntheic_dataset.csv'

# %%
# Copy the data for backup
df = data.copy()

# %%
# Getting feel of the data
df.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(Â°C)  Humidity(%)  \
# 0  10/04/2021               2104    18              21.2           48
# 1   6/06/2018               2163    18              26.6           56
# 2   6/05/2018                385     9              19.1           52
# 3   6/05/2018                598     3              19.1           77
# 4   6/03/2018               2104    19              27.4           48
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(Â°C)  \
# 0               2.2            1084.0                        16.2
# 1               2.5            1469.0                        15.9
# 2               0.6            1666.0                        13.9
# 3               0.6             399.0                        13.9
# 4               2.4            1084.0                         7.7
#
#    Solar Radiation (MJ/m2)  Rainfall(mm) Seasons     Holiday Functioning Day
# 0                     1.80           0.0  Summer     Holiday             Yes
# 1                     0.51           0.0  Summer     Holiday             Yes
# 2                     0.00           0.0  Winter  No Holiday             Yes
# 3                     0.20           0.0  Winter  No Holiday             Yes
# 4                     1.80           0.0  Summer     Holiday             Yes

# %%
df.tail()
# Out:
#             Date  Rented Bike Count  Hour  Temperature(Â°C)  Humidity(%)  \
# 9995  12/04/2017                303     4          2.800000           90
# 9996   6/02/2018               2788    19         25.400000           51
# 9997  17/06/2021                495    14         38.189676           62
# 9998   9/03/2022                488    19         14.190201           49
# 9999   9/06/2022                443     4         11.012606           84
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(Â°C)  \
# 9995          1.500000        194.000000                    1.100000
# 9996          2.700000       2000.000000                    7.900000
# 9997          2.918127         10.728618                   30.578347
# 9998          3.476976          6.066853                    8.263891
# 9999          4.264615         13.917402                    2.162540
#
#       Solar Radiation (MJ/m2)  Rainfall(mm) Seasons     Holiday  \
# 9995                 0.000000           0.0  Winter  No Holiday
# 9996                 0.120000           0.0  Summer  No Holiday
# 9997                20.167731           0.0  Summer          No
# 9998                16.101686           0.0  Winter          No
# 9999                17.296772           0.0  Winter          No
#
#      Functioning Day
# 9995             Yes
# 9996             Yes
# 9997              No
# 9998             Yes
# 9999              No

# %%
# Data shape
df.shape
# Out:
# (10000, 13)

# %%
# data dtype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        10000 non-null  object
#  1   Rented Bike Count           10000 non-null  int64
#  2   Hour                        10000 non-null  int64
#  3   Temperature(Â°C)            10000 non-null  float64
#  4   Humidity(%)                 10000 non-null  int64
#  5   Wind speed (m/s)            10000 non-null  float64
#  6   Visibility (10m)            10000 non-null  float64
#  7   Dew point temperature(Â°C)  10000 non-null  float64
#  8   Solar Radiation (MJ/m2)     10000 non-null  float64
#  9   Rainfall(mm)                9999 non-null   float64
#  10  Seasons                     10000 non-null  object
#  11  Holiday                     10000 non-null  object
#  12  Functioning Day             10000 non-null  object
# dtypes: float64(6), int64(3), object(4)
# memory usage: 1015.8+ KB

# %%
# Statistical info
df.describe(include='all').transpose()
# Out:
#                               count unique        top  freq        mean  \
# Date                          10000    352  6/04/2018   393         NaN
# Rented Bike Count           10000.0    NaN        NaN   NaN    449.8243
# Hour                        10000.0    NaN        NaN   NaN     10.9978
# Temperature(Â°C)            10000.0    NaN        NaN   NaN   22.965513
# Humidity(%)                 10000.0    NaN        NaN   NaN     61.3653
# Wind speed (m/s)            10000.0    NaN        NaN   NaN    2.775099
# Visibility (10m)            10000.0    NaN        NaN   NaN  362.088873
# Dew point temperature(Â°C)  10000.0    NaN        NaN   NaN   14.848433
# Solar Radiation (MJ/m2)     10000.0    NaN        NaN   NaN   11.737535
# Rainfall(mm)                 9999.0    NaN        NaN   NaN    3.239073
# Seasons                       10000      3     Summer  3680         NaN
# Holiday                       10000      4         No  4313         NaN
# Functioning Day               10000      2        Yes  6352         NaN
#
#                                    std       min        25%        50%  \
# Date                               NaN       NaN        NaN        NaN
# Rented Bike Count           504.019399      13.0      165.0      339.5
# Hour                          7.046244       0.0        4.0       11.0
# Temperature(Â°C)              9.710682      -8.1  19.572761       23.3
# Humidity(%)                  15.915162      21.0       48.0       62.0
# Wind speed (m/s)              1.277005       0.0   1.769549        2.7
# Visibility (10m)            684.272145  5.004294  10.728618  15.372305
# Dew point temperature(Â°C)   10.228413     -22.0       10.3  15.554762
# Solar Radiation (MJ/m2)       7.932857       0.0   5.367546  12.036416
# Rainfall(mm)                  5.400187       0.0        0.0        0.0
# Seasons                            NaN       NaN        NaN        NaN
# Holiday                            NaN       NaN        NaN        NaN
# Functioning Day                    NaN       NaN        NaN        NaN
#
#                                   75%        max
# Date                              NaN        NaN
# Rented Bike Count               449.0     3380.0
# Hour                             18.0       23.0
# Temperature(Â°C)                 29.0  39.979087
# Humidity(%)                      74.0       92.0
# Wind speed (m/s)             3.870698        5.8
# Visibility (10m)             19.75842     2000.0
# Dew point temperature(Â°C)  20.908972  34.164809
# Solar Radiation (MJ/m2)     18.873474  24.947351
# Rainfall(mm)                 5.479183  19.752959
# Seasons                           NaN        NaN
# Holiday                           NaN        NaN
# Functioning Day                   NaN        NaN

# %% [markdown]
# #<b> Preprocessing the data

# %%
# Checking na values of data
df.isna().sum()
# Out:
# Date                          0
# Rented Bike Count             0
# Hour                          0
# Temperature(Â°C)              0
# Humidity(%)                   0
# Wind speed (m/s)              0
# Visibility (10m)              0
# Dew point temperature(Â°C)    0
# Solar Radiation (MJ/m2)       0
# Rainfall(mm)                  1
# Seasons                       0
# Holiday                       0
# Functioning Day               0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
# Checking duplicate
df.duplicated().sum()
# Out:
# 4171

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
# converting date column dtype object to date
df['Date']=pd.to_datetime(df['Date'], format="%d/%m/%Y")

# %%
# split day of week, month and year in three column
df['day_of_week'] = df['Date'].dt.day_name() # extract week name from Date column
df["month"] = df['Date'].dt.month_name()   # extract month name from Date column
df["year"] = df['Date'].map(lambda x: x.year).astype("object")     # extract year from Date column and convert it in object type

# %%
df['month'].unique()
# Out:
# array(['April', 'June', 'May', 'March', 'February', 'July', 'January',
#        'December', 'October', 'September', 'November', 'August'],
#       dtype=object)

# %%
# drop the Date column
df.drop(columns=['Date'],inplace=True)

# %% [markdown]
# <b> When we observe the data we realize that Hour column is a numerical column but it is a time stamp so we have to treat Hour as a categorical feature

# %%
# convert Hour column integer to Categorical
df['Hour']=df['Hour'].astype('object')

# %%
# Divide Data in categorical and numerical features
numeric_features= df.select_dtypes(exclude='object')
categorical_features=df.select_dtypes(include='object')

# %% [markdown]
# #<b> Exploratory data analysis

# %% [markdown]
# ##<b> categorical_features

# %%
categorical_features.head()
# Out:
#   Hour Seasons     Holiday Functioning Day day_of_week  month  year
# 0   18  Summer     Holiday             Yes    Saturday  April  2021
# 1   18  Summer     Holiday             Yes   Wednesday   June  2018
# 2    9  Winter  No Holiday             Yes      Sunday    May  2018
# 3    3  Winter  No Holiday             Yes      Sunday    May  2018
# 4   19  Summer     Holiday             Yes     Tuesday  March  2018

# %%
# checking categorical column value count
for i in categorical_features.columns:
  if i == "year":
    continue
  print("\n ")
  print('column name  : ', i)
  print(df[i].value_counts())
# Out:
#
# column name  :  Hour
# Hour
# 18    465
# 2     377
# 9     320
# 5     317
# 4     313
# 11    301
# 17    280
# 3     279
# 12    275
# 21    270
# 7     253
# 0     251
# 1     245
# 20    229
# 19    225
# 8     212
# 23    206
# 16    199
# 10    161
# 22    155
# 13    152
# 14    126
# 15    115
# 6     102
# Name: count, dtype: int64
#
#
# column name  :  Seasons
# Seasons
# Summer    2265
# Rainy     1865
# Winter    1698
# Name: count, dtype: int64
#
#
# column name  :  Holiday
# Holiday
# No            2093
# No Holiday    1866
# Yes           1731
# Holiday        138
# Name: count, dtype: int64
#
#
# column name  :  Functioning Day
# Functioning Day
# Yes    4017
# No     1811
# Name: count, dtype: int64
#
#
# column name  :  day_of_week
# day_of_week
# Friday       1126
# Sunday       1088
# Wednesday     954
# Tuesday       920
# Saturday      615
# Thursday      588
# Monday        537
# Name: count, dtype: int64
#
#
# column name  :  month
# month
# April        947
# February     781
# March        713
# May          660
# December     541
# January      536
# July         448
# June         396
# September    257
# November     224
# August       176
# October      149
# Name: count, dtype: int64

# %%
df["Holiday"].replace(["Yes","No"],["Holiday","No Holiday"],inplace=True)

# %% [markdown]
# <b> Explore our categorical feature and Trying to take some important information from the categorical feature

# %%
# we create point plots with Rented Bike Count during different categorical features with respect of Hour
for i in categorical_features.columns:
  if i == 'Hour' or i=="year":
    pass
  else:
    plt.figure(figsize=(20,10))
    sns.pointplot(x=df["Hour"],y=df['Rented Bike Count'],hue=df[i])
    plt.title(f"Rented Bike Count during different {i} with respect of Hour")
  plt.show()

# %% [markdown]
# <b> Some more experiments for our categorical features

# %%
# Converting days of weeks in Two variable from Monaday to Friday in Weekdays and Saturday and Sunday to Weekend
df['week'] = df['day_of_week'].apply(lambda x:'Weekend'  if x=='Saturday' or  x== 'Sunday' else 'Weekdays')

# %%
# value counts of Week column
df.week.value_counts()
# Out:
# week
# Weekdays    4125
# Weekend     1703
# Name: count, dtype: int64

# %%
# Getting feel of week column with pointplot
plt.figure(figsize=(15,7))
sns.pointplot(x=df["Hour"],y=df['Rented Bike Count'],hue=df['week'])
plt.title("Rented Bike Count during weekday and weekend with respect of Hour")
# Out:
# Text(0.5, 1.0, 'Rented Bike Count during weekday and weekend with respect of Hour')

# %% [markdown]
# <b>Now we can clearly see the pattern which shows that the demand is high in the morning and afternoon on the weekend. While there is more demand during office hours in weekdays

# %% [markdown]
# <b>Now we can drop the days of week column

# %%
# droping the days of week column from df and from categorical feature
df.drop(columns=['day_of_week'], inplace=True)
categorical_features.drop(columns=['day_of_week'], inplace=True)

# %% [markdown]
# <b> Value counts in percentage

# %%
# using for loop and getting all value Counts in percentage of categorical features
for i in categorical_features.columns:
  if i== "year":
    continue
  print('feature name : ',i)
  print(df[i].value_counts(normalize=True))
  print('\n')
# Out:
# feature name :  Hour
# Hour
# 18    0.079787
# 2     0.064688
# 9     0.054907
# 5     0.054393
# 4     0.053706
# 11    0.051647
# 17    0.048044
# 3     0.047872
# 12    0.047186
# 21    0.046328
# 7     0.043411
# 0     0.043068
# 1     0.042038
# 20    0.039293
# 19    0.038607
# 8     0.036376
# 23    0.035347
# 16    0.034146
# 10    0.027625
# 22    0.026596
# 13    0.026081
# 14    0.021620
# 15    0.019732
# 6     0.017502
# Name: proportion, dtype: float64
#
#
# feature name :  Seasons
# Seasons
# Summer    0.388641
# Rainy     0.320007
# Winter    0.291352
# Name: proportion, dtype: float64
#
#
# feature name :  Holiday
# Holiday
# No Holiday    0.679307
# Holiday       0.320693
# Name: proportion, dtype: float64
#
#
# feature name :  Functioning Day
# Functioning Day
# Yes    0.689259
# No     0.310741
# Name: proportion, dtype: float64
#
#
# feature name :  month
# month
# April        0.162491
# February     0.134008
# March        0.122340
# May          0.113246
# December     0.092828
# January      0.091970
# July         0.076870
# June         0.067948
# September    0.044097
# November     0.038435
# August       0.030199
# October      0.025566
# Name: proportion, dtype: float64

# %% [markdown]
# <b> lets take a visualization of value counts

# %%
# creating boxplot plot and bar plot
n=1
for i in categorical_features.columns:
  plt.figure(figsize=(15,15))
  plt.subplot(6,2,n)
  n+=1
  print('\n')
  print('='*70,i,'='*70)
  print('\n')
  n+= 1
  sns.barplot(x=df[i],y=df['Rented Bike Count'])
  plt.tight_layout()
  plt.show()
# Out:
# ====================================================================== Hour ======================================================================
# ====================================================================== Seasons ======================================================================
# ====================================================================== Holiday ======================================================================
# ====================================================================== Functioning Day ======================================================================
# ====================================================================== month ======================================================================
# ====================================================================== year ======================================================================

# %%
# creating pieplot for all categorical feature
n=1
plt.figure(figsize=(20,15))
for i in categorical_features.columns:
  plt.subplot(3,3,n)
  n=n+1
  plt.pie(df[i].value_counts(),labels = df[i].value_counts().keys().tolist(),autopct='%.0f%%')
  plt.title(i)
  plt.tight_layout()

# %% [markdown]
# ##<b> Numeric features

# %% [markdown]
# <b> Now the time of Explore our numerical feature and trying to take some important information from the Numeical feature

# %% [markdown]
# <b> Very less columns are linearly related with our dependent variable

# %% [markdown]
# ##<b> Let's try something else to get information from our Numerical features

# %%
#plotting histogram with mean and median of all the numeric features of the dataset
n=1
for i in numeric_features.columns:
  plt.figure(figsize=(20,40))
  plt.subplot(9,2,n)
  n+=1
  print('\n')
  print('='*70,i,'='*70)
  print('\n')
  feature=df[i]
  feature.hist(bins=50,edgecolor="black")
  plt.axvline(feature.mean(), color='magenta', linestyle='dashed', linewidth=2)
  plt.axvline(feature.median(), color='cyan', linestyle='dashed', linewidth=2)
  n+= 1
  plt.show()
# Out:
# ====================================================================== Rented Bike Count ======================================================================
# ====================================================================== Temperature(Â°C) ======================================================================
# ====================================================================== Humidity(%) ======================================================================
# ====================================================================== Wind speed (m/s) ======================================================================
# ====================================================================== Visibility (10m) ======================================================================
# ====================================================================== Dew point temperature(Â°C) ======================================================================
# ====================================================================== Solar Radiation (MJ/m2) ======================================================================
# ====================================================================== Rainfall(mm) ======================================================================

# %% [markdown]
# <b>In histplot plots we observe that some of our columns is right skewed and some are left skewed we have to remember this things when we apply algorithms
#
# <b>From Histogram we are coming to know that the features which are skewed, their mean and the median are also skewed, which was understood by looking at the graph that this would happen.

# %% [markdown]
# <b> *Lets try to find how is the relation of numerical features with our dependent variable*

# %%
# Regression plot to know relation with our independent variable
n=1
plt.figure(figsize=(15,15))
for i in numeric_features.columns:
  if i == 'Rented Bike Count':
    pass
  else:
    plt.subplot(4,2,n)
    n+=1
    sns.regplot(x=df[i], y=df['Rented Bike Count'],scatter_kws={"color": "cyan"}, line_kws={"color": "red"})
    plt.title(f'Dependend variable and {i}')
    plt.tight_layout()

# %% [markdown]
# <b>This regression plots shows that some of our features are positive linear and some are negative linear in relation to our target variable.

# %% [markdown]
# #<b> Correlation

# %% [markdown]
# <b> Now is the time to know what is the correlation of our dependent variable with the independent numerical features

# %%
# using seaborn heatmap for ploting correlation graph
plt.figure(figsize=(10,8))
sns.heatmap(abs(numeric_features.corr()), cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Model Traning and Testing

# %%
df.head()
# Out:
#    Rented Bike Count Hour  Temperature(Â°C)  Humidity(%)  Wind speed (m/s)  \
# 0               2104   18              21.2           48               2.2
# 1               2163   18              26.6           56               2.5
# 2                385    9              19.1           52               0.6
# 3                598    3              19.1           77               0.6
# 4               2104   19              27.4           48               2.4
#
#    Visibility (10m)  Dew point temperature(Â°C)  Solar Radiation (MJ/m2)  \
# 0            1084.0                        16.2                     1.80
# 1            1469.0                        15.9                     0.51
# 2            1666.0                        13.9                     0.00
# 3             399.0                        13.9                     0.20
# 4            1084.0                         7.7                     1.80
#
#    Rainfall(mm) Seasons     Holiday Functioning Day  month  year      week
# 0           0.0  Summer     Holiday             Yes  April  2021   Weekend
# 1           0.0  Summer     Holiday             Yes   June  2018  Weekdays
# 2           0.0  Winter  No Holiday             Yes    May  2018   Weekend
# 3           0.0  Winter  No Holiday             Yes    May  2018   Weekend
# 4           0.0  Summer     Holiday             Yes  March  2018  Weekdays

# %%
df.drop(columns=['month', 'year', 'week'],inplace=True)
df["Seasons"].replace(['Winter', 'Summer', 'Rainy'], [0, 1, 2], inplace=True)
df["Holiday"] = (df["Holiday"] == 'Holiday')
df["Functioning Day"] = (df["Functioning Day"] == 'Yes')

# %%
X=df.drop(columns=["Rented Bike Count"])
X.head(2)
# Out:
#   Hour  Temperature(Â°C)  Humidity(%)  Wind speed (m/s)  Visibility (10m)  \
# 0   18              21.2           48               2.2            1084.0
# 1   18              26.6           56               2.5            1469.0
#
#    Dew point temperature(Â°C)  Solar Radiation (MJ/m2)  Rainfall(mm)  Seasons  \
# 0                        16.2                     1.80           0.0        1
# 1                        15.9                     0.51           0.0        1
#
#    Holiday  Functioning Day
# 0     True             True
# 1     True             True

# %%
y=df["Rented Bike Count"]
y.head(2)
# Out:
# 0    2104
# 1    2163
# Name: Rented Bike Count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=4276)

# %% [markdown]
# *   LINEAR REGRESSION

# %%
model_LR=LinearRegression()
model_LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model_LR.predict(X_test)
y_pred
# Out:
# array([ 474.36943048, 1405.32604591,  591.60882088, ...,   23.60199101,
#         260.39342953,  385.66786695])

# %%
LR_r2=r2_score(y_pred=y_pred,y_true=y_test)
LR_r2
# Out:
# 0.4418230431779091

# %%
LR_MAE=mean_absolute_error(y_pred=y_pred,y_true=y_test)
LR_MAE
# Out:
# 299.6654685848817

# %% [markdown]
# *   DECISION TREE

# %%
# rState=0
# DT_r2 = 0
# while DT_r2 < 0.99:

#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25,random_state=rState)
#     model_DT = DecisionTreeRegressor()

#     model_DT.fit(X_train, y_train)
#     y_pred=model_DT.predict(X_test)
#     DT_r2 = r2_score(y_pred=y_pred, y_true=y_test)
#     if DT_r2 > 0.98:
#         print(f"rState : {rState} ---- DT_r2 : {DT_r2}")
#     rState+=1
# print(rState)

# %%
model_DT = DecisionTreeRegressor()
model_DT.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=model_DT.predict(X_test)
y_pred
# Out:
# array([ 148., 2246.,  491., ...,  400.,  154.,  374.])

# %%
DT_r2=r2_score(y_pred=y_pred,y_true=y_test)
DT_r2
# Out:
# 0.9808409093173858

# %%
DT_MAE=mean_absolute_error(y_pred=y_pred,y_true=y_test)
DT_MAE
# Out:
# 16.389155799588195

# %% [markdown]
# *   RANDOM FOREST

# %%
model_RF=RandomForestRegressor(n_estimators=16)
model_RF.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=16)

# %%
y_pred=model_RF.predict(X_test)
y_pred
# Out:
# array([ 148.    , 2246.    ,  480.8125, ...,  400.    ,  154.    ,
#         356.1875])

# %%
RF_r2=r2_score(y_pred=y_pred,y_true=y_test)
RF_r2
# Out:
# 0.9727842710971214

# %%
RF_MAE=mean_absolute_error(y_pred=y_pred,y_true=y_test)
RF_MAE
# Out:
# 33.3272756520247

# %%
# Create a list of tuples with the algorithm names, R2 scores, and MAEs
results = [
    ('Linear Regression', LR_r2, LR_MAE),
    ('Decision Tree Regressor', DT_r2, DT_MAE),
    ('Random Forest Regressor', RF_r2, RF_MAE),
]

# Create a DataFrame from the results
df = pd.DataFrame(results, columns=['Algorithm', 'R2_Score', 'MAE'])

# Print the DataFrame
df
# Out:
#                  Algorithm  R2_Score         MAE
# 0        Linear Regression  0.441823  299.665469
# 1  Decision Tree Regressor  0.980841   16.389156
# 2  Random Forest Regressor  0.972784   33.327276

# %% [markdown]
# *   ANOVA

# %%
from sklearn.feature_selection import f_regression,SelectKBest
k=11
selector= SelectKBest(score_func=f_regression,k=k)

# %%
X_train_selected=selector.fit_transform(X_train,y_train)
X_test_selected=selector.transform(X_test)

# %%
model_Anova=DecisionTreeRegressor()
model_Anova.fit(X_train_selected,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=model_Anova.predict(X_test_selected)
y_pred
# Out:
# array([ 148., 2246.,  491., ...,  400.,  154.,  374.])

# %%
Anova_r2=r2_score(y_pred=y_pred,y_true=y_test)
Anova_r2
# Out:
# 0.9852816787883831

# %%
Anova_MAE=mean_absolute_error(y_pred=y_pred,y_true=y_test)
Anova_MAE
# Out:
# 14.312971859986273

# %% [markdown]
# * SVM

# %%
from sklearn.svm import SVR

SVR_model=SVR(kernel="linear",C=1)
SVR_model.fit(X_train,y_train)
# Out:
# SVR(C=1, kernel='linear')

# %%
y_pred=SVR_model.predict(X_test)
y_pred
# Out:
# array([ 405.92538337, 1077.50425951,  403.94423791, ...,  192.67388625,
#         288.7371933 ,  399.02109992])

# %%
SVR_r2=r2_score(y_pred=y_pred,y_true=y_test)
SVR_r2
# Out:
# 0.3843114271331587

# %%
SVR_MAE=mean_absolute_error(y_pred=y_pred,y_true=y_test)
SVR_MAE
# Out:
# 281.3989055839889

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve


def plot_learning_curve(estimator, X, y, title):
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, train_sizes=np.linspace(0.1, 1.0, 10), cv=5)

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)

    plt.figure()
    plt.title(title)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt


plot_learning_curve(model_LR, X_train, y_train,
                    "Learning Curve (Linear Regression)")
plt.show()

plot_learning_curve(model_DT, X_train, y_train,
                    "Learning Curve (Decision Tree)")
plt.show()

plot_learning_curve(model_RF, X_train, y_train,
                    "Learning Curve (Random Forest)")
plt.show()

plot_learning_curve(model_Anova, X_train, y_train,
                    "Learning Curve (Anova)")
plt.show()

plot_learning_curve(SVR_model, X_train, y_train,
                    "Learning Curve (SVM)")
plt.show()

# %%
results = [
    ('ANOVA', Anova_r2, Anova_MAE),
    ('SVM', SVR_r2, SVR_MAE),
]

new_df = pd.DataFrame(results, columns=['Algorithm', 'R2_Score', 'MAE'])

df=pd.concat([df,new_df],ignore_index=True)
df
# Out:
#                  Algorithm  R2_Score         MAE
# 0        Linear Regression  0.441823  299.665469
# 1  Decision Tree Regressor  0.980841   16.389156
# 2  Random Forest Regressor  0.972784   33.327276
# 3                    ANOVA  0.985282   14.312972
# 4                      SVM  0.384311  281.398906

# %%
plt.figure(figsize=(20,10))
colors=['red','green','blue','yellow','orange']
plt.bar(height=df['R2_Score'], x = 'Algorithm', data=df,color=colors)
plt.title("R2 Score with respect of Models",fontsize=15)
plt.show()

# %%
plt.figure(figsize=(20,10))
colors=['red','green','blue','yellow','orange']
plt.bar(height=df['MAE'], x = 'Algorithm', data=df,color=colors)
plt.title("MAE Score with respect of Models",fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure(figsize=(20,10))
#       2 colors=['red','green','blue','yellow','orange']
#       3 plt.bar(height=df['MAE'], x = 'Algorithm', data=df,color=colors)
#
# NameError: name 'plt' is not defined
